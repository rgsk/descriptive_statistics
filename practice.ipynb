# %%
data = {
  "data": {
    "attribute_values": [
      {
        "name": "Compact Blue",
        "sub_name": "25L"
      },
      {
        "name": "Revolution Blue",
        "sub_name": "21.5L"
      },
      {
        "name": "Revolution Grey",
        "sub_name": "21.5L"
      },
      {
        "name": "128 GB",
        "sub_name": ""
      },
      {
        "name": "256 GB",
        "sub_name": ""
      },
      {
        "name": "Red",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "L",
        "sub_name": ""
      },
      {
        "name": "XL",
        "sub_name": ""
      },
      {
        "name": "XXL",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": "physics"
      },
      {
        "name": "Chemistry",
        "sub_name": "Chemistry"
      },
      {
        "name": "Biology",
        "sub_name": "Biology"
      },
      {
        "name": "Mathematics",
        "sub_name": "Mathematics"
      },
      {
        "name": "Zoology",
        "sub_name": "Zoology"
      },
      {
        "name": "Botany",
        "sub_name": "Botany"
      },
      {
        "name": "Physical Chemistry",
        "sub_name": "Physical-Chemistry"
      },
      {
        "name": "Organic Chemistry",
        "sub_name": "Organic-Chemistry"
      },
      {
        "name": "Inorganic Chemistry",
        "sub_name": "Inorganic-Chemistry"
      },
      {
        "name": "9th",
        "sub_name": "10th"
      },
      {
        "name": "Class 10th",
        "sub_name": "3 months"
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "Solid",
        "sub_name": ""
      },
      {
        "name": "Printed",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "BOARDS",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "Zoology",
        "sub_name": ""
      },
      {
        "name": "Botany",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "PCMB",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "White",
        "sub_name": ""
      },
      {
        "name": "Single Unit",
        "sub_name": ""
      },
      {
        "name": "Set of 3",
        "sub_name": ""
      },
      {
        "name": "Set of 6",
        "sub_name": ""
      },
      {
        "name": "Pack of 10",
        "sub_name": ""
      },
      {
        "name": "Teal",
        "sub_name": ""
      },
      {
        "name": "Light Blue",
        "sub_name": ""
      },
      {
        "name": "test",
        "sub_name": "test"
      },
      {
        "name": "T-shirts",
        "sub_name": ""
      },
      {
        "name": "Bags",
        "sub_name": ""
      },
      {
        "name": "Bottles",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": "physics"
      },
      {
        "name": "Chemistry",
        "sub_name": "c"
      },
      {
        "name": "Class 9th",
        "sub_name": "3 months"
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "6 months",
        "sub_name": ""
      },
      {
        "name": "3 months",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "PCMB",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "Light Pink",
        "sub_name": ""
      },
      {
        "name": "S",
        "sub_name": ""
      },
      {
        "name": "Orange",
        "sub_name": ""
      },
      {
        "name": "Royal Blue",
        "sub_name": ""
      },
      {
        "name": "Hindi",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "Crash Course",
        "sub_name": ""
      },
      {
        "name": "MTG",
        "sub_name": ""
      },
      {
        "name": "Cengage",
        "sub_name": ""
      },
      {
        "name": "Arihant",
        "sub_name": ""
      },
      {
        "name": "Balaji Publications",
        "sub_name": ""
      },
      {
        "name": "Bharti Bhawan",
        "sub_name": ""
      },
      {
        "name": "2021",
        "sub_name": ""
      },
      {
        "name": "2022",
        "sub_name": ""
      },
      {
        "name": "Fair Notebooks",
        "sub_name": "fair"
      },
      {
        "name": "Practice Notebooks",
        "sub_name": "practice"
      },
      {
        "name": "2023 Edition",
        "sub_name": ""
      },
      {
        "name": "Shirts",
        "sub_name": "shirts"
      },
      {
        "name": "XS",
        "sub_name": ""
      },
      {
        "name": "M",
        "sub_name": ""
      },
      {
        "name": "Blue",
        "sub_name": "blue-color"
      },
      {
        "name": "Green",
        "sub_name": "green-color"
      },
      {
        "name": "Red",
        "sub_name": "red-color"
      },
      {
        "name": "500ml",
        "sub_name": "500ml-sub"
      },
      {
        "name": "1000ml",
        "sub_name": "1000ml-sub"
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "Red",
        "sub_name": None
      },
      {
        "name": "Blue",
        "sub_name": None
      },
      {
        "name": "White",
        "sub_name": None
      },
      {
        "name": "Large",
        "sub_name": None
      },
      {
        "name": "Small",
        "sub_name": "S"
      },
      {
        "name": "Medium",
        "sub_name": "M"
      }
    ]
  }
}

# %%
data = {
  "data": {
    "attribute_values": [
      {
        "name": "Oswal",
        "sub_name": ""
      },
      {
        "name": "Sultan Chand",
        "sub_name": ""
      },
      {
        "name": "Commerce",
        "sub_name": ""
      },
      {
        "name": "Pack of 20",
        "sub_name": ""
      },
      {
        "name": "Blue",
        "sub_name": ""
      },
      {
        "name": "Green",
        "sub_name": ""
      },
      {
        "name": "S. Chand",
        "sub_name": ""
      },
      {
        "name": "Disha Publication",
        "sub_name": ""
      },
      {
        "name": "General Knowledge",
        "sub_name": ""
      },
      {
        "name": "300 Pages",
        "sub_name": ""
      },
      {
        "name": "280 Pages",
        "sub_name": ""
      },
      {
        "name": "128 GB",
        "sub_name": ""
      },
      {
        "name": "256 GB",
        "sub_name": ""
      },
      {
        "name": "Red",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "XS",
        "sub_name": ""
      },
      {
        "name": "S",
        "sub_name": ""
      },
      {
        "name": "M",
        "sub_name": ""
      },
      {
        "name": "L",
        "sub_name": ""
      },
      {
        "name": "XL",
        "sub_name": ""
      },
      {
        "name": "XXL",
        "sub_name": ""
      },
      {
        "name": "Hindi",
        "sub_name": None
      },
      {
        "name": "English",
        "sub_name": None
      },
      {
        "name": "5U Blister Pack",
        "sub_name": ""
      },
      {
        "name": "Compact Blue 25L",
        "sub_name": ""
      },
      {
        "name": "Revolution Blue 21.5L",
        "sub_name": ""
      },
      {
        "name": "Revolution Grey 21.5L",
        "sub_name": ""
      },
      {
        "name": "Classmate",
        "sub_name": "Invento"
      },
      {
        "name": "Doms",
        "sub_name": "geomiti"
      },
      {
        "name": "256 Pages",
        "sub_name": "Set of 5"
      },
      {
        "name": "75 x 75 mm",
        "sub_name": "4 color"
      },
      {
        "name": "Solid",
        "sub_name": ""
      },
      {
        "name": "Printed",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "Oddy",
        "sub_name": "15 gm"
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "Crash Course",
        "sub_name": ""
      },
      {
        "name": "Study/Laptop Table",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "Lexicon",
        "sub_name": ""
      },
      {
        "name": "Spectrum Books",
        "sub_name": ""
      },
      {
        "name": "Prabhat Prakashan ",
        "sub_name": ""
      },
      {
        "name": "Glue & Gluestick",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "PCMB",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "White",
        "sub_name": ""
      },
      {
        "name": "Single Unit",
        "sub_name": ""
      },
      {
        "name": "Set of 3",
        "sub_name": ""
      },
      {
        "name": "Pack of 10",
        "sub_name": ""
      },
      {
        "name": "Teal",
        "sub_name": ""
      },
      {
        "name": "Orange",
        "sub_name": ""
      },
      {
        "name": "Royal Blue",
        "sub_name": ""
      },
      {
        "name": "Light Pink",
        "sub_name": ""
      },
      {
        "name": "Light Blue",
        "sub_name": ""
      },
      {
        "name": "Coffee",
        "sub_name": ""
      },
      {
        "name": "Red and White",
        "sub_name": ""
      },
      {
        "name": "Royal Blue and White",
        "sub_name": ""
      },
      {
        "name": "NDA",
        "sub_name": ""
      },
      {
        "name": "Hindi",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "Dhanpatrai Publication",
        "sub_name": ""
      },
      {
        "name": "25U Jar",
        "sub_name": ""
      },
      {
        "name": "Grey",
        "sub_name": ""
      },
      {
        "name": "T-shirts",
        "sub_name": ""
      },
      {
        "name": "Bags",
        "sub_name": ""
      },
      {
        "name": "Bottles",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "Bharati Bhawan",
        "sub_name": ""
      },
      {
        "name": "Cengage",
        "sub_name": ""
      },
      {
        "name": "Arihant",
        "sub_name": ""
      },
      {
        "name": "MTG",
        "sub_name": ""
      },
      {
        "name": "Camlin",
        "sub_name": "Exam"
      },
      {
        "name": "Camlin",
        "sub_name": "Scholar"
      },
      {
        "name": "172 Pages",
        "sub_name": "Set of 6"
      },
      {
        "name": "25 x 75 mm",
        "sub_name": "3 color"
      },
      {
        "name": "15 x 75 mm",
        "sub_name": "5 color"
      },
      {
        "name": "Charcoal Grey",
        "sub_name": ""
      },
      {
        "name": "Hoodies",
        "sub_name": ""
      },
      {
        "name": "Crash Course",
        "sub_name": ""
      },
      {
        "name": "Fevistik",
        "sub_name": "15 gm"
      },
      {
        "name": "Oddy",
        "sub_name": "8 gm"
      },
      {
        "name": "Geometry Box",
        "sub_name": ""
      },
      {
        "name": "Sticky Notes & Flags",
        "sub_name": ""
      },
      {
        "name": "Pravalika Publications",
        "sub_name": ""
      },
      {
        "name": "Rawat Publication",
        "sub_name": ""
      },
      {
        "name": "GATE",
        "sub_name": ""
      },
      {
        "name": "UPSC",
        "sub_name": ""
      },
      {
        "name": "Faber Castell",
        "sub_name": "5 Units"
      },
      {
        "name": "Multiple Brands",
        "sub_name": "Mini Combo"
      },
      {
        "name": "Multiple Brands",
        "sub_name": "Mega Combo"
      },
      {
        "name": "Luxor",
        "sub_name": "5 Units"
      },
      {
        "name": "Wireless",
        "sub_name": ""
      },
      {
        "name": "Wired",
        "sub_name": ""
      },
      {
        "name": "Active Black",
        "sub_name": ""
      },
      {
        "name": "Ivory White",
        "sub_name": ""
      },
      {
        "name": "Fast-Selling",
        "sub_name": ""
      },
      {
        "name": "Best-Seller",
        "sub_name": ""
      },
      {
        "name": "PW",
        "sub_name": ""
      },
      {
        "name": "Faber-Castell",
        "sub_name": ""
      },
      {
        "name": "Classmate",
        "sub_name": ""
      },
      {
        "name": "Cello",
        "sub_name": ""
      },
      {
        "name": "Linc",
        "sub_name": ""
      },
      {
        "name": "Luxor",
        "sub_name": ""
      },
      {
        "name": "Oddy",
        "sub_name": ""
      },
      {
        "name": "Buoyant Black",
        "sub_name": ""
      },
      {
        "name": "Red",
        "sub_name": ""
      },
      {
        "name": "Rust",
        "sub_name": ""
      },
      {
        "name": "Multiple Brands",
        "sub_name": ""
      },
      {
        "name": "Blue",
        "sub_name": ""
      },
      {
        "name": "Camlin",
        "sub_name": ""
      },
      {
        "name": "Doms",
        "sub_name": ""
      },
      {
        "name": "Hinglish",
        "sub_name": ""
      },
      {
        "name": "Doms",
        "sub_name": "Geommy"
      },
      {
        "name": "Pens, Pencils & Highlighters",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "Leopard",
        "sub_name": ""
      },
      {
        "name": "Clear",
        "sub_name": ""
      },
      {
        "name": "Anti Blue-light Glasses",
        "sub_name": ""
      },
      {
        "name": "Matt Black",
        "sub_name": ""
      },
      {
        "name": "McGraw Hill",
        "sub_name": ""
      },
      {
        "name": "Oxford University",
        "sub_name": ""
      },
      {
        "name": "Wiley",
        "sub_name": ""
      },
      {
        "name": "CAT",
        "sub_name": ""
      },
      {
        "name": "CUET",
        "sub_name": ""
      },
      {
        "name": "White/Chalk Board",
        "sub_name": ""
      },
      {
        "name": "Re-stocking Soon",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "Altis Vortex",
        "sub_name": ""
      },
      {
        "name": "New",
        "sub_name": ""
      },
      {
        "name": "Boards",
        "sub_name": ""
      },
      {
        "name": "Algebra",
        "sub_name": ""
      },
      {
        "name": "Trigonometry",
        "sub_name": ""
      },
      {
        "name": "Coordinate Geometry",
        "sub_name": ""
      },
      {
        "name": "Differential Calculus",
        "sub_name": ""
      },
      {
        "name": "Integral Calculus",
        "sub_name": ""
      },
      {
        "name": "Vectors & 3D Geometry",
        "sub_name": ""
      },
      {
        "name": "Play with Graphs",
        "sub_name": ""
      },
      {
        "name": "Waves & Thermodynamics",
        "sub_name": ""
      },
      {
        "name": "Optics & Modern Physics",
        "sub_name": ""
      },
      {
        "name": "Electricity & Magnetism",
        "sub_name": ""
      },
      {
        "name": "Mechanics Vol 1",
        "sub_name": ""
      },
      {
        "name": "Mechanics Vol 2",
        "sub_name": ""
      },
      {
        "name": "Volume 1",
        "sub_name": ""
      },
      {
        "name": "Volume 2",
        "sub_name": ""
      },
      {
        "name": "Vol 1 & 2 Combo",
        "sub_name": ""
      },
      {
        "name": "JEE/NEET",
        "sub_name": ""
      },
      {
        "name": "JEE/Boards",
        "sub_name": ""
      },
      {
        "name": "NEET/Boards",
        "sub_name": ""
      },
      {
        "name": "Organic Chemistry Part 1",
        "sub_name": ""
      },
      {
        "name": "Organic Chemistry Part 2",
        "sub_name": ""
      },
      {
        "name": "Inorganic Chemistry Part 1",
        "sub_name": ""
      },
      {
        "name": "Inorganic Chemistry Part 2",
        "sub_name": ""
      },
      {
        "name": "Physical Chemistry Part 1",
        "sub_name": ""
      },
      {
        "name": "Physical Chemistry Part 2",
        "sub_name": ""
      },
      {
        "name": "Electrostatics & Current Electricity",
        "sub_name": ""
      },
      {
        "name": "Magnetism & Electromagnetic Induction",
        "sub_name": ""
      },
      {
        "name": "Verbal Ability & Reading Comprehension",
        "sub_name": ""
      },
      {
        "name": "Logical Reasoning",
        "sub_name": ""
      },
      {
        "name": "Quantitative Aptitude",
        "sub_name": ""
      },
      {
        "name": "Teaching",
        "sub_name": ""
      },
      {
        "name": "Set of 2",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": "Single Unit"
      },
      {
        "name": "Chemistry",
        "sub_name": "Single Unit"
      },
      {
        "name": "Biology",
        "sub_name": "Single Unit"
      },
      {
        "name": "Phy-Chem-Bio",
        "sub_name": "Set of 3"
      },
      {
        "name": "Physics-Chemistry",
        "sub_name": "Set of 2"
      },
      {
        "name": "Green",
        "sub_name": ""
      },
      {
        "name": "6 MM",
        "sub_name": ""
      },
      {
        "name": "4 MM",
        "sub_name": ""
      },
      {
        "name": "Multipurpose Mat",
        "sub_name": ""
      },
      {
        "name": "SSC",
        "sub_name": ""
      },
      {
        "name": "Solo",
        "sub_name": ""
      },
      {
        "name": "Files & Folders",
        "sub_name": ""
      },
      {
        "name": "Daily Planner",
        "sub_name": ""
      },
      {
        "name": "Weekly Planner",
        "sub_name": ""
      },
      {
        "name": "O-Ring Binder",
        "sub_name": ""
      },
      {
        "name": "Strip Folder",
        "sub_name": ""
      },
      {
        "name": "Swing Clip Folder",
        "sub_name": ""
      },
      {
        "name": "Pencil Pouch",
        "sub_name": ""
      },
      {
        "name": "My Zipper Pouch",
        "sub_name": ""
      },
      {
        "name": "Pouches, Storage Case & Organisers",
        "sub_name": ""
      },
      {
        "name": "Exam Essentials",
        "sub_name": ""
      },
      {
        "name": "Foundation",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "Pink",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "Phys & Chem",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Phys & Chem",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Crash Course",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "Boards",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "Hindi",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "Physics",
        "sub_name": ""
      },
      {
        "name": "Chemistry",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "Compact Blue 30L",
        "sub_name": ""
      },
      {
        "name": "Black and Blue",
        "sub_name": ""
      },
      {
        "name": "Utility 22L",
        "sub_name": ""
      },
      {
        "name": "On Sale",
        "sub_name": ""
      },
      {
        "name": "On Sale",
        "sub_name": ""
      },
      {
        "name": "On Sale",
        "sub_name": ""
      },
      {
        "name": "On Sale",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": "1 Unit"
      },
      {
        "name": "Blue",
        "sub_name": "1 Unit"
      },
      {
        "name": "Black & Blue + Duster",
        "sub_name": "3 Units"
      },
      {
        "name": "Price Drop",
        "sub_name": ""
      },
      {
        "name": "NEET",
        "sub_name": ""
      },
      {
        "name": "JEE",
        "sub_name": ""
      },
      {
        "name": "Board Exams",
        "sub_name": ""
      },
      {
        "name": "9th",
        "sub_name": ""
      },
      {
        "name": "10th",
        "sub_name": ""
      },
      {
        "name": "11th",
        "sub_name": ""
      },
      {
        "name": "12th",
        "sub_name": ""
      },
      {
        "name": "1 month",
        "sub_name": ""
      },
      {
        "name": "3 months",
        "sub_name": ""
      },
      {
        "name": "6 months",
        "sub_name": ""
      },
      {
        "name": "Dropper",
        "sub_name": ""
      },
      {
        "name": "All Subjects",
        "sub_name": ""
      },
      {
        "name": "Science",
        "sub_name": ""
      },
      {
        "name": "SST",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "CUET",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "General Test",
        "sub_name": ""
      },
      {
        "name": "Mathematics",
        "sub_name": ""
      },
      {
        "name": "Economics",
        "sub_name": ""
      },
      {
        "name": "History",
        "sub_name": ""
      },
      {
        "name": "Political Science",
        "sub_name": ""
      },
      {
        "name": "Phys & Chem",
        "sub_name": ""
      },
      {
        "name": "Pidilite",
        "sub_name": ""
      },
      {
        "name": "11/12/12+",
        "sub_name": ""
      },
      {
        "name": "11/12/12+",
        "sub_name": ""
      },
      {
        "name": "GATE",
        "sub_name": ""
      },
      {
        "name": "Yellow",
        "sub_name": ""
      },
      {
        "name": "CAPS",
        "sub_name": ""
      },
      {
        "name": "Coffee Mugs",
        "sub_name": ""
      },
      {
        "name": "PW \"Raste Badlo Manzil nahi\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW \"सपना बडा हो तो संघर्ष छोटा कैसे हो सकता है?\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW \"#BMS = BRAIN ME SET\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW \"AB BATON SE NAHIN RAATON SE LADNA HAI\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW \"No Struggle No Progress No Success\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW \"Mano toh mauj hai warna samasya toh roz hai\" printed coffee mug",
        "sub_name": None
      },
      {
        "name": "PW Logo Printed Coffee Mug",
        "sub_name": None
      },
      {
        "name": "Science",
        "sub_name": ""
      },
      {
        "name": "Notebooks, Registers & Practical Files",
        "sub_name": ""
      },
      {
        "name": "Diary, Planners & Calendars",
        "sub_name": ""
      },
      {
        "name": "It's going tibia Okay",
        "sub_name": None
      },
      {
        "name": "Albert Einstein",
        "sub_name": None
      },
      {
        "name": "Powered By Coffee and Mitochondria",
        "sub_name": None
      },
      {
        "name": "Apple Pie",
        "sub_name": None
      },
      {
        "name": "Open Minded",
        "sub_name": None
      },
      {
        "name": "Schrodinger's Cat",
        "sub_name": None
      },
      {
        "name": "Best Value",
        "sub_name": ""
      },
      {
        "name": "Recommended",
        "sub_name": ""
      },
      {
        "name": "Black",
        "sub_name": ""
      },
      {
        "name": "Calculus",
        "sub_name": ""
      },
      {
        "name": "2 ft x 3 ft",
        "sub_name": ""
      },
      {
        "name": "1.5 ft x 2 ft",
        "sub_name": ""
      },
      {
        "name": "Pride Cap Combo",
        "sub_name": "Bag, Bottle & Cap"
      },
      {
        "name": "Nazariya Combo",
        "sub_name": "Bag, Bottle & Glasses"
      },
      {
        "name": "Table + 4 mm Mat",
        "sub_name": ""
      },
      {
        "name": "Table + 6 mm Mat",
        "sub_name": ""
      },
      {
        "name": "School Essential-Nazariya",
        "sub_name": "Notebooks, Pens, Bag, Bottle, Glasses"
      },
      {
        "name": "School Essential-Pride Cap",
        "sub_name": "Notebooks, Pens, Bag, Bottle, Cap"
      },
      {
        "name": "Mega Combo",
        "sub_name": ""
      },
      {
        "name": "Mini Combo",
        "sub_name": ""
      },
      {
        "name": "Sold Out",
        "sub_name": ""
      },
      {
        "name": "Deep Blue",
        "sub_name": ""
      },
      {
        "name": "Geography",
        "sub_name": ""
      },
      {
        "name": "Business Studies",
        "sub_name": ""
      },
      {
        "name": "English",
        "sub_name": ""
      },
      {
        "name": "Back in Stock",
        "sub_name": ""
      },
      {
        "name": "Mathematics",
        "sub_name": ""
      },
      {
        "name": "English & General Knowledge",
        "sub_name": ""
      },
      {
        "name": "Maths + English-GK Combo",
        "sub_name": ""
      },
      {
        "name": "पाई पाई जोड़ के ये T-shirt ली है",
        "sub_name": ""
      },
      {
        "name": "White on Black Symbols",
        "sub_name": ""
      },
      {
        "name": "The Fall of Gravity",
        "sub_name": ""
      },
      {
        "name": "Schrodinger's Cat Black",
        "sub_name": ""
      },
      {
        "name": "Projectile Motion Equation",
        "sub_name": ""
      },
      {
        "name": "Biology",
        "sub_name": ""
      },
      {
        "name": "The Fall of Gravity",
        "sub_name": ""
      },
      {
        "name": "New Launch",
        "sub_name": ""
      },
      {
        "name": "New Launch",
        "sub_name": ""
      },
      {
        "name": "Oddy",
        "sub_name": "17 gm"
      },
      {
        "name": "PW Logo Printed Black Coffee Mug",
        "sub_name": ""
      },
      {
        "name": "Tablets",
        "sub_name": ""
      },
      {
        "name": "Headphones/Earbuds",
        "sub_name": ""
      },
      {
        "name": "Deli",
        "sub_name": ""
      },
      {
        "name": "Kangaro",
        "sub_name": ""
      },
      {
        "name": "Casio",
        "sub_name": ""
      },
      {
        "name": "Scissors, Cutters, Stapler & Punching Machine",
        "sub_name": ""
      },
      {
        "name": "Calculators",
        "sub_name": ""
      },
      {
        "name": "BOARDS",
        "sub_name": ""
      },
      {
        "name": "PCMB",
        "sub_name": ""
      },
      {
        "name": "Laptop Stand",
        "sub_name": ""
      },
      {
        "name": "Kickstart Combo",
        "sub_name": ""
      },
      {
        "name": "Essential Combo",
        "sub_name": ""
      },
      {
        "name": "Maha Combo",
        "sub_name": ""
      },
      {
        "name": "GATE",
        "sub_name": ""
      },
      {
        "name": "Pre-order",
        "sub_name": ""
      },
      {
        "name": "Pre-order",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "Maths",
        "sub_name": ""
      },
      {
        "name": "Hindi",
        "sub_name": ""
      },
      {
        "name": "Stationery Combo",
        "sub_name": ""
      },
      {
        "name": " Pre-order",
        "sub_name": ""
      },
      {
        "name": "PCM",
        "sub_name": ""
      },
      {
        "name": "PCB",
        "sub_name": ""
      },
      {
        "name": "Pen Drive Courses",
        "sub_name": ""
      },
      {
        "name": "Tablet Courses",
        "sub_name": ""
      },
      {
        "name": "Tablet Courses + PW Study Material",
        "sub_name": ""
      },
      {
        "name": "Accountancy",
        "sub_name": "accountancy"
      },
      {
        "name": "UPSC CSE",
        "sub_name": ""
      },
      {
        "name": "NDA/NA",
        "sub_name": ""
      },
      {
        "name": "CA",
        "sub_name": ""
      },
      {
        "name": "UP PSC",
        "sub_name": ""
      },
      {
        "name": "BPSC",
        "sub_name": ""
      },
      {
        "name": "MPSC",
        "sub_name": ""
      },
      {
        "name": "Modules",
        "sub_name": ""
      },
      {
        "name": "Test Series",
        "sub_name": ""
      },
      {
        "name": "Previous Year Papers",
        "sub_name": ""
      },
      {
        "name": "2021 Edition",
        "sub_name": ""
      },
      {
        "name": "2022 Edition",
        "sub_name": ""
      },
      {
        "name": "2023 Edition",
        "sub_name": ""
      },
      {
        "name": "Free Shipping",
        "sub_name": ""
      },
      {
        "name": "8th",
        "sub_name": ""
      },
      {
        "name": "Science",
        "sub_name": ""
      },
      {
        "name": "Social Studies",
        "sub_name": ""
      },
      {
        "name": "SSC",
        "sub_name": ""
      },
      {
        "name": "SD Card Course",
        "sub_name": ""
      },
      {
        "name": "Marathi",
        "sub_name": ""
      },
      {
        "name": "Marathi",
        "sub_name": ""
      }
    ]
  }
}

# %%
print(data)
# Out:
# {'data': {'attribute_values': [{'name': 'Oswal', 'sub_name': ''}, {'name': 'Sultan Chand', 'sub_name': ''}, {'name': 'Commerce', 'sub_name': ''}, {'name': 'Pack of 20', 'sub_name': ''}, {'name': 'Blue', 'sub_name': ''}, {'name': 'Green', 'sub_name': ''}, {'name': 'S. Chand', 'sub_name': ''}, {'name': 'Disha Publication', 'sub_name': ''}, {'name': 'General Knowledge', 'sub_name': ''}, {'name': '300 Pages', 'sub_name': ''}, {'name': '280 Pages', 'sub_name': ''}, {'name': '128 GB', 'sub_name': ''}, {'name': '256 GB', 'sub_name': ''}, {'name': 'Red', 'sub_name': ''}, {'name': 'Black', 'sub_name': ''}, {'name': 'XS', 'sub_name': ''}, {'name': 'S', 'sub_name': ''}, {'name': 'M', 'sub_name': ''}, {'name': 'L', 'sub_name': ''}, {'name': 'XL', 'sub_name': ''}, {'name': 'XXL', 'sub_name': ''}, {'name': 'Hindi', 'sub_name': None}, {'name': 'English', 'sub_name': None}, {'name': '5U Blister Pack', 'sub_name': ''}, {'name': 'Compact Blue 25L', 'sub_name': ''}, {'name': 'Revolution Blue 21.5L', 's
# ...

# %%
import pandas as pd
import numpy as np

# %%
# Extract attribute_values from the data dictionary
attribute_values = data['data']['attribute_values']

# Create a pandas DataFrame
df = pd.DataFrame(attribute_values)

# Calculate the length for missing values as NaN
df['name_len'] = df['name'].apply(lambda x: len(str(x)) if pd.notnull(x) and str(x) != '' else np.nan)
df['sub_name_len'] = df['sub_name'].apply(lambda x: len(str(x)) if pd.notnull(x) and str(x) != '' else np.nan)

# Calculate the mean length for missing values
mean_name_len = df['name_len'].mean()
mean_sub_name_len = df['sub_name_len'].mean()

# Fill the NaN values with the mean length
df['name_len'].fillna(mean_name_len, inplace=True)
df['sub_name_len'].fillna(mean_sub_name_len, inplace=True)

# %%
df
# Out:
#                name sub_name  name_len  sub_name_len
# 0             Oswal                  5      9.935484
# 1      Sultan Chand                 12      9.935484
# 2          Commerce                  8      9.935484
# 3        Pack of 20                 10      9.935484
# 4              Blue                  4      9.935484
# ..              ...      ...       ...           ...
# 370  Social Studies                 14      9.935484
# 371             SSC                  3      9.935484
# 372  SD Card Course                 14      9.935484
# 373         Marathi                  7      9.935484
# 374         Marathi                  7      9.935484
#
# [375 rows x 4 columns]

# %%
# Run describe method on len
description = df[['name_len', 'sub_name_len']].describe()

print(description)
# Out:
#          name_len  sub_name_len
# count  375.000000    375.000000
# mean    11.061333      9.935484
# std      9.451762      2.146924
# min      1.000000      4.000000
# 25%      5.000000      9.935484
# 50%      8.000000      9.935484
# 75%     14.000000      9.935484
# max     67.000000     37.000000

# %%
# Filter rows with length above the mean for 'name' or 'sub_name'
filtered_df = df[df['name_len'] < 50 ]
# filtered_df['sub_name_len'] = filtered_df['sub_name'].apply(lambda x : 0 if x != None else len(x))
filtered_df.sort_values(by='sub_name_len',ascending=False,inplace=True)
filtered_df.sort_values(by='name_len',ascending=False,inplace=True)
print(filtered_df)
# Out:
#                                                 name sub_name  name_len
# 278  PW "Raste Badlo Manzil nahi" printed coffee mug     None        47  \
# 333    Scissors, Cutters, Stapler & Punching Machine                 45
# 280      PW "#BMS = BRAIN ME SET" printed coffee mug     None        43
# 186           Verbal Ability & Reading Comprehension                 38
# 286           Notebooks, Registers & Practical Files                 38
# ..                                               ...      ...       ...
# 15                                                XS                  2
# 124                                               PW                  2
# 17                                                 M                  1
# 18                                                 L                  1
# 16                                                 S                  1
#
#      sub_name_len
# 278      9.935484
# 333      9.935484
# 280      9.935484
# 186      9.935484
# ...
